# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

df = pd.read_csv("insurance_data.csv")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age','affordibility']],df.bought_insurance,test_size=0.2)
X_train
# Out:
#     age  affordibility
# 3    52              0
# 11   28              1
# 19   18              1
# 14   49              1
# 6    55              0
# 0    22              1
# 8    62              1
# 16   25              0
# 15   55              1
# 22   40              1
# 27   46              1
# 26   23              1
# 2    47              1
# 24   50              1
# 4    46              1
# 23   45              1
# 1    25              0
# 5    56              1
# 18   19              0
# 21   26              0
# 25   54              1
# 17   58              1

# %%
y_train
# Out:
# 3     0
# 11    0
# 19    0
# 14    1
# 6     0
# 0     0
# 8     1
# 16    1
# 15    1
# 22    1
# 27    0
# 26    0
# 2     1
# 24    1
# 4     1
# 23    1
# 1     0
# 5     1
# 18    0
# 21    0
# 25    1
# 17    1
# Name: bought_insurance, dtype: int64

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age'] / 100

# %%
model = keras.Sequential([
    keras.layers.Dense(2, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.add(keras.layers.Dense(2, activation='relu'))
# 3 te yapabilirsin. Fakat bu durumda training iin 3 sınıfın olması gerekiyor
#model.add(keras.layers.Dense(2, activation='sigmoid'))

# 1-0 arasında değer üretiyor
# tek sınıf çıktısı
#model.compile(optimizer='adam',
#              loss='binary_crossentropy',
#              metrics=['accuracy'])

# sigorta yapıp yapmayacağını yüzdesel yakınlık olarak gösteriyor. MNIST gibi
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 879ms/step - accuracy: 0.5455 - loss: 0.6905
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5455 - loss: 0.6903
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5455 - loss: 0.6902
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5455 - loss: 0.6900
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5455 - loss: 0.6899
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5455 - loss: 0.6897
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5455 - loss: 0.6896
# Epoch 8/50
# ...

# %%
# 6 satırlık test veri seti içerisinde %50 yi aşan sigorta yaptırıyor demek
model.predict(X_test_scaled)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ddc8f874040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# array([[0.73107004, 0.82484895],
#        [0.61563164, 0.67484504],
#        [0.5524402 , 0.592946  ],
#        [0.54825675, 0.5875245 ],
#        [0.7903202 , 0.90157825],
#        [0.7356675 , 0.8308034 ]], dtype=float32)

# %%
# 1 olanlar sigorta yaptırmış.
# yukarısı ile karşılaştırılınca 27 0 yanlış tahmin olmuş
# geri kalanı doğru tahmin
y_test
# Out:
# 10    0
# 7     1
# 13    0
# 12    0
# 9     1
# 20    0
# Name: bought_insurance, dtype: int64

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.3333 - loss: 0.7077
# [0.7077236771583557, 0.3333333432674408]
